# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
p=sns.load_dataset('penguins')
p
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.swarmplot(x='species',y='body_mass_g',data=p)

# %%
sns.swarmplot(x='island',y='body_mass_g',data=p)

# %%
sns.swarmplot(x='island',y='body_mass_g',data=p,hue = 'island') #get legend

# %%
sns.swarmplot(x='species',y='body_mass_g',data=p)

# %%
sns.swarmplot(x='island',y='body_mass_g',data=p,hue = 'species') #get legend

# %%
sns.violinplot(x='body_mass_g',data=p) # get legend

# %%
sns.violinplot(x='island', y = 'body_mass_g' , data=p)

# %%
sns.violinplot(x='island', y = 'body_mass_g' , data=p,hue='island')

# %%
sns.swarmplot(x = 'body_mass_g' , data=p)

# %%
sns.violinplot(x = 'body_mass_g' , data=p) #violin plot prefer

# %%
sns.boxplot(x = 'body_mass_g' , data=p)

# %%
sns.kdeplot(x = 'body_mass_g' , data=p,shade = True)

# %%
sns.swarmplot(x = 'body_mass_g' , data=p)
sns.violinplot(x = 'body_mass_g' , data=p)
sns.boxplot(x = 'body_mass_g' , data=p)
sns.kdeplot(x = 'body_mass_g' , data=p,shade = True)

# %%
fig,axs = plt.subplots(nrows=4)
fig.set_size_inches(10,10)

# %%
fig,axs = plt.subplots(nrows=4)
fig.set_size_inches(10,10)
sns.swarmplot(x = 'body_mass_g' , data=p , ax=axs[0])
sns.violinplot(x = 'body_mass_g' , data=p,ax=axs[1])
sns.boxplot(x = 'body_mass_g' , data=p,ax=axs[2])
sns.kdeplot(x = 'body_mass_g' , data=p,shade = True,ax=axs[3])

# %%
sns.violinplot(x='species',y='body_mass_g',data=p)

# %%
sns.violinplot(x='sex',y='body_mass_g',data=p)

# %%
sns.swarmplot(x='island',y='flipper_length_mm',data=p,hue='sex')

# %%
sns.swarmplot(x='island',y='flipper_length_mm',data=p[p.sex == 'Female'])

# %%
sns.swarmplot(x='island',y='flipper_length_mm',data=p,hue='sex',split=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3002: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 8.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.violinplot(x='island',y='flipper_length_mm',data=p,hue='sex',split=True)

# %%
sns.violinplot(x='island',y='flipper_length_mm',data=p,hue='sex',split=True,inner='quartile')

# %%
sns.swarmplot(x='island',y='flipper_length_mm',hue='species',split=True,data=p)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3002: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 11.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 36.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 8.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
p['binary_species']=p.species.apply(lambda x : 'Gentoo' if x=='Gentoo' else 'Adelie | Chinstrap')
p
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex      binary_species
# 0         3750.0    Male  Adelie | Chinstrap
# ...

# %%
sns.violinplot(x='island', y='flipper_length_mm', hue='binary_species',split= True,data=p)
